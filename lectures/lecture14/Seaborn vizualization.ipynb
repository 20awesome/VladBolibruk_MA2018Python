# %%
# IMPORTING REQUIRED LIBRARIES & ASSIGNING ALIASES:
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Loading built-in Datasets:
iris = sns.load_dataset("iris")
iris.head(40)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.set()
# %matplotlib inline

sns.swarmplot(x="species", y="petal_length", data=iris)

# %%
# Loading Pandas DataFrame:
df = pd.read_csv('./data/fatal-police-shootings-data.csv', encoding='windows-1252')
df.head(10)
# Out:
#    id                 name        date   manner_of_death       armed   age  \
# 0   3           Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4     Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5   John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8      Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9    Michael Rodriguez  2015-01-04              shot    nail gun  39.0
# 5  11    Kenneth Joe Brown  2015-01-04              shot         gun  18.0
# 6  13  Kenneth Arnold Buck  2015-01-05              shot         gun  22.0
# 7  15        Brock Nichols  2015-01-06              shot         gun  35.0
# 8  16        Autumn Steele  2015-01-06              shot     unarmed  34.0
# 9  17      Leslie Sapp III  2015-01-06              shot  toy weapon  47.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# ...

# %%
df.describe()
# Out:
#                 id          age
# count  4054.000000  3898.000000
# mean   2269.788604    36.891483
# std    1269.726799    13.125567
# min       3.000000     6.000000
# 25%    1170.250000    27.000000
# 50%    2259.500000    35.000000
# 75%    3371.750000    45.000000
# max    4465.000000    91.000000

# %%
sns.stripplot(x="armed", y="age", data=df, orient="v")

# %%
tips = sns.load_dataset("tips")
sns.barplot(x="day", y="total_bill", data=tips)
# Out:
# /home/wizard/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set_style("whitegrid")
sns.boxplot(x="day",y="total_bill", data=tips)

# %%
sns.set_style("ticks")
sns.boxplot(x="day",y="total_bill", data=tips)

# %%
def sinplot(flip=1):
    x = np.linspace(0,14,100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
        
with sns.axes_style("darkgrid"):
    plt.subplot(211)
    sinplot()
plt.subplot(212)
sinplot(-1)

# %%
#sns.set(style="whitegrid", rc={"grid.linewidth": 1.5})
#sns.set_context("poster", font_scale=2.5, rc={"grid.linewidth": 5.0})
sinplot()

# %%
tips = sns.load_dataset("tips")
sns.regplot(x="total_bill",y="tip",data=tips)
# Out:
# /home/wizard/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
nobs, nvars = 100, 5
data = np.random.random((nobs, nvars))
columns = ['Variable {}'.format(i) for i in range(1, nvars + 1)]
df = pd.DataFrame(data, columns=columns)
#df.head()
sns.pairplot(df)

# %%
sns.set(rc={"figure.figsize": (6, 6)})
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
sample_colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple", "pale red", "medium green", "denim blue"]
sns.palplot(sns.xkcd_palette(sample_colors))

# %%
sns.palplot(sns.color_palette("cubehelix", 9))

# %%
sns.palplot(sns.cubehelix_palette(8))

# %%
x, y = np.random.multivariate_normal([0, 0], [[1, -.5], [-.5, 1]], size=300).T
sample_cmap = sns.cubehelix_palette(light = 1, as_cmap=True)
sns.kdeplot(x, y, cmap=sample_cmap, shade=True)
# Out:
# /home/wizard/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set_style("whitegrid")
sns.swarmplot(x="day", y="total_bill", data=tips, palette="viridis")

# %% [markdown]
# [colors.png](./images/colors.png)

# %%
sns.set(style="whitegrid", palette="hsv")
sns.lmplot(x="total_bill", y="tip", data=tips)
# Out:
# /home/wizard/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(style="whitegrid", palette="hsv")
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)
# Out:
# /home/wizard/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips, markers=['o', 'x'], palette="Set1", legend=False)
# Out:
# /home/wizard/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x="total_bill", y="tip", col="smoker", data=tips)
# Out:
# /home/wizard/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x="total_bill", y="tip", palette="magma", row="sex", col="time", data=tips, size=5)
# Out:
# /home/wizard/anaconda3/lib/python3.6/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /home/wizard/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
